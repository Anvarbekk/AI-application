# %% [markdown]
# <a href="https://colab.research.google.com/github/Anvarbekk/AI-application/blob/main/Week_11_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
url = 'https://raw.githubusercontent.com/NVDLI/LDL/main/pt_framework/utilities.py'
r = requests.get(url)

with open( 'utilities.py','w') as f:
  f.write(r.text)

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader 
import numpy as np 
import matplotlib.pyplot as plt
from utilities import train_model

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
EPOCHS = 100
BATCH_SIZE = 16

TRAIN_TEST_SPLIT = 0.8
MIN = 12
FILE_NAME = '/content/book_store_sales.csv'

def readfile(file_name):
    file = open(file_name, 'r', encoding='utf-8')
    next(file)
    data = []
    for line in (file):
        values = line.split(',')
        data.append(float(values[1]))
    file.close()
    return np.array(data, dtype=np.float32)

# Read data and split up into train and test data.
sales = readfile(FILE_NAME)
months = len(sales)
split = int(months * TRAIN_TEST_SPLIT)
train_sales = sales[0:split]
test_sales = sales[split:]

# %%
# Plot dataset 
x = range(len(sales))
plt.plot(x, sales, 'r-', label='book sales')
plt.title('Book store sales') 
plt.axis([0, 339, 0.0, 3000.0]) 
plt.xlabel ('Months')
plt.ylabel('Sales (millions $) ')
plt.legend()
plt.show()

# %%
# Plot naive prediction
test_output = test_sales [MIN:]
naive_prediction = test_sales [MIN-1:-1]
x= range(len(test_output))
plt.plot(x, test_output, 'g-', label='test_output') 
plt.plot(x, naive_prediction, 'm-' , label='naive prediction')
plt.title('Book store sales')
plt.axis([0, len(test_output), 0.0, 3000.0]) 
plt.xlabel ('months')
plt.ylabel('Monthly book store sales')
plt.legend()
plt.show()

# %%
# Standardize train and test data.
# Use only training seasons to compute mean and stddev.
mean = np.mean(train_sales)
stddev = np.std(train_sales)
train_sales_std = (train_sales - mean) /stddev
test_sales_std = (test_sales - mean) /stddev

# %%
# Create train examples
train_months = len(train_sales)
train_X = np.zeros((train_months-MIN, train_months-1, 1), dtype=np.float32)
train_y = np.zeros((train_months-MIN, 1), dtype=np.float32)
for i in range(0, train_months-MIN):
  train_X[i,-(i+MIN):, 0] = train_sales_std[0: i+MIN]
  train_y[i, 0] = train_sales_std[i+MIN]
# Create test examples
test_months = len(test_sales)
test_X = np.zeros((test_months-MIN, test_months-1, 1), dtype=np.float32)
test_y = np.zeros((test_months-MIN, 1), dtype=np.float32)
for i in range(0, test_months-MIN):
  test_X[i, -(i+MIN):, 0] = test_sales_std[0: i+MIN]
  test_y[i, 0] = test_sales_std[i+MIN]

# Create Dataset objects
trainset = TensorDataset(torch.from_numpy(train_X).clone(), torch.from_numpy(train_y))
testset = TensorDataset(torch.from_numpy(test_X).clone(), torch.from_numpy (test_y))

# %%
# Custom layer that retrieves only last time step from RNN output.

class LastTimestep(nn.Module):
  def forward(self, inputs):
    return inputs [1][0]

# Create RNN model
model = nn.Sequential(
    nn.RNN(1, 128, nonlinearity='relu', batch_first=True),
    LastTimestep(),
    nn.Linear (128, 1)
)
# Loss function and optimizer.
optimizer = torch.optim.Adam(model.parameters())
loss_function = nn.MSELoss()

# Train model.
train_model(model, device, EPOCHS, BATCH_SIZE, trainset, testset,
            optimizer, loss_function, 'mae')
# Out:
# Epoch 1/100 loss: 0.8983 - mae: 0.7079 - val_loss: 1.1522 - val_mae: 0.8407
# Epoch 2/100 loss: 0.7619 - mae: 0.6275 - val_loss: 1.0502 - val_mae: 0.7956
# Epoch 3/100 loss: 0.6057 - mae: 0.5947 - val_loss: 0.8027 - val_mae: 0.6815
# Epoch 4/100 loss: 0.5364 - mae: 0.5422 - val_loss: 0.7458 - val_mae: 0.6607
# Epoch 5/100 loss: 0.4992 - mae: 0.5357 - val_loss: 0.5983 - val_mae: 0.5968
# Epoch 6/100 loss: 0.4763 - mae: 0.5098 - val_loss: 0.4803 - val_mae: 0.5045
# Epoch 7/100 loss: 0.5676 - mae: 0.5798 - val_loss: 0.3941 - val_mae: 0.4267
# Epoch 8/100 loss: 0.4725 - mae: 0.4969 - val_loss: 0.3967 - val_mae: 0.4791
# Epoch 9/100 loss: 0.4151 - mae: 0.4666 - val_loss: 0.5355 - val_mae: 0.5648
# Epoch 10/100 loss: 0.5758 - mae: 0.5374 - val_loss: 0.3900 - val_mae: 0.4980
# Epoch 11/100 loss: 0.5094 - mae: 0.5361 - val_loss: 0.3612 - val_mae: 0.4599
# Epoch 12/100 loss: 0.3841 - mae: 0.4705 - val_loss: 0.2622 - val_mae: 0.3123
# Epoch 13/100 loss: 0.3618 - mae: 0.4595 - val_loss: 0.2414 - val_mae: 0.3390
# Epoch 14/100 loss: 0.3513 - mae: 0.4381 - val_loss: 0.2344 - val_mae: 0.3136
# Epoch 15/100 loss: 0.3815 - mae: 0.4505 - val_loss: 0.2862 - val_mae: 0.3998
# Epoch 16/100 loss: 0.3331 - mae: 0.4213 - val_loss: 0.2159 - val_mae: 0.2776
# Epoch 17/100 loss: 0.2846 - mae: 0.3901 - val_loss: 0.1957 - val_mae: 0.2875
# Epoch 18/100 loss: 0.3088 - mae: 0.4149 - val_loss: 0.1957 - val_mae: 0.2945
# Epoch 19/100 loss: 0.2794 - mae: 0.3836 - val_loss: 0.2051 - val_mae: 0.2645
# Epoch 20/100 loss: 0.2783 - mae: 0.3746 - val_loss: 0.2761 - val_mae: 0.4118
# Epoch 21/100 loss: 0.5116 - mae: 0.4783 - val_loss: 0.2253 - val_mae: 0.3075
# Epoch 22/100 loss: 0.4298 - mae: 0.4191 - val_loss: 0.2421 - val_mae: 0.3285
# Epoch 23/100 loss: 0.3064 - mae: 0.3998 - val_loss: 0.2547 - val_mae: 0.2827
# Epoch 24/100 loss: 0.2507 - mae: 0.3640 - val_loss: 0.2189 - val_mae: 0.2763
# Epoch 25/100 loss: 0.1980 - mae: 0.3218 - val_loss: 0.2015 - val_mae: 0.3053
# Epoch 26/100 loss: 0.2166 - mae: 0.3394 - val_loss: 0.1570 - val_mae: 0.2529
# Epoch 27/100 loss: 0.1694 - mae: 0.2947 - val_loss: 0.1419 - val_mae: 0.2262
# Epoch 28/100 loss: 0.1358 - mae: 0.2677 - val_loss: 0.1150 - val_mae: 0.2029
# Epoch 29/100 loss: 0.1183 - mae: 0.2508 - val_loss: 0.0965 - val_mae: 0.1805
# Epoch 30/100 loss: 0.0983 - mae: 0.2239 - val_loss: 0.0912 - val_mae: 0.1787
# Epoch 31/100 loss: 0.0901 - mae: 0.2124 - val_loss: 0.0804 - val_mae: 0.1460
# Epoch 32/100 loss: 0.0824 - mae: 0.2044 - val_loss: 0.0730 - val_mae: 0.1421
# Epoch 33/100 loss: 0.0749 - mae: 0.1949 - val_loss: 0.0745 - val_mae: 0.1338
# Epoch 34/100 loss: 0.0727 - mae: 0.1919 - val_loss: 0.0582 - val_mae: 0.1280
# Epoch 35/100 loss: 0.0694 - mae: 0.1887 - val_loss: 0.0676 - val_mae: 0.1432
# Epoch 36/100 loss: 0.0599 - mae: 0.1762 - val_loss: 0.0853 - val_mae: 0.1551
# Epoch 37/100 loss: 0.0654 - mae: 0.1793 - val_loss: 0.0744 - val_mae: 0.1444
# Epoch 38/100 loss: 0.0602 - mae: 0.1740 - val_loss: 0.0801 - val_mae: 0.1486
# Epoch 39/100 loss: 0.0539 - mae: 0.1625 - val_loss: 0.0807 - val_mae: 0.1454
# Epoch 40/100 loss: 0.0536 - mae: 0.1649 - val_loss: 0.0760 - val_mae: 0.1485
# Epoch 41/100 loss: 0.0523 - mae: 0.1616 - val_loss: 0.0529 - val_mae: 0.1205
# Epoch 42/100 loss: 0.0451 - mae: 0.1480 - val_loss: 0.0595 - val_mae: 0.1241
# Epoch 43/100 loss: 0.0436 - mae: 0.1503 - val_loss: 0.0533 - val_mae: 0.1258
# Epoch 44/100 loss: 0.0452 - mae: 0.1519 - val_loss: 0.0590 - val_mae: 0.1256
# Epoch 45/100 loss: 0.0503 - mae: 0.1589 - val_loss: 0.0910 - val_mae: 0.1656
# Epoch 46/100 loss: 0.0529 - mae: 0.1633 - val_loss: 0.0850 - val_mae: 0.1542
# Epoch 47/100 loss: 0.0546 - mae: 0.1669 - val_loss: 0.0720 - val_mae: 0.1441
# Epoch 48/100 loss: 0.0474 - mae: 0.1552 - val_loss: 0.0463 - val_mae: 0.1081
# Epoch 49/100 loss: 0.0401 - mae: 0.1394 - val_loss: 0.0505 - val_mae: 0.1030
# Epoch 50/100 loss: 0.0371 - mae: 0.1383 - val_loss: 0.0510 - val_mae: 0.1084
# Epoch 51/100 loss: 0.0367 - mae: 0.1352 - val_loss: 0.0464 - val_mae: 0.1030
# Epoch 52/100 loss: 0.0372 - mae: 0.1336 - val_loss: 0.0560 - val_mae: 0.1114
# Epoch 53/100 loss: 0.0396 - mae: 0.1465 - val_loss: 0.0528 - val_mae: 0.1229
# Epoch 54/100 loss: 0.0392 - mae: 0.1475 - val_loss: 0.0506 - val_mae: 0.1081
# Epoch 55/100 loss: 0.0339 - mae: 0.1344 - val_loss: 0.0518 - val_mae: 0.1075
# Epoch 56/100 loss: 0.0345 - mae: 0.1319 - val_loss: 0.0508 - val_mae: 0.1059
# Epoch 57/100 loss: 0.0422 - mae: 0.1470 - val_loss: 0.0523 - val_mae: 0.1314
# Epoch 58/100 loss: 0.0331 - mae: 0.1323 - val_loss: 0.0489 - val_mae: 0.1149
# Epoch 59/100 loss: 0.0368 - mae: 0.1368 - val_loss: 0.0481 - val_mae: 0.1157
# Epoch 60/100 loss: 0.0328 - mae: 0.1323 - val_loss: 0.0559 - val_mae: 0.1236
# Epoch 61/100 loss: 0.0307 - mae: 0.1292 - val_loss: 0.0561 - val_mae: 0.1299
# Epoch 62/100 loss: 0.0280 - mae: 0.1207 - val_loss: 0.0440 - val_mae: 0.1022
# Epoch 63/100 loss: 0.0268 - mae: 0.1187 - val_loss: 0.0555 - val_mae: 0.1241
# Epoch 64/100 loss: 0.0274 - mae: 0.1191 - val_loss: 0.0769 - val_mae: 0.1414
# Epoch 65/100 loss: 0.0263 - mae: 0.1192 - val_loss: 0.0645 - val_mae: 0.1297
# Epoch 66/100 loss: 0.0258 - mae: 0.1172 - val_loss: 0.0759 - val_mae: 0.1394
# Epoch 67/100 loss: 0.0243 - mae: 0.1141 - val_loss: 0.0472 - val_mae: 0.1105
# Epoch 68/100 loss: 0.0223 - mae: 0.1110 - val_loss: 0.0493 - val_mae: 0.1168
# Epoch 69/100 loss: 0.0225 - mae: 0.1121 - val_loss: 0.0426 - val_mae: 0.1094
# Epoch 70/100 loss: 0.0231 - mae: 0.1100 - val_loss: 0.0371 - val_mae: 0.0976
# Epoch 71/100 loss: 0.0232 - mae: 0.1109 - val_loss: 0.0480 - val_mae: 0.1175
# Epoch 72/100 loss: 0.0222 - mae: 0.1108 - val_loss: 0.0529 - val_mae: 0.1296
# Epoch 73/100 loss: 0.0218 - mae: 0.1063 - val_loss: 0.0391 - val_mae: 0.1006
# Epoch 74/100 loss: 0.0225 - mae: 0.1086 - val_loss: 0.0519 - val_mae: 0.1196
# Epoch 75/100 loss: 0.0210 - mae: 0.1061 - val_loss: 0.0454 - val_mae: 0.1081
# Epoch 76/100 loss: 0.0189 - mae: 0.1020 - val_loss: 0.0784 - val_mae: 0.1579
# Epoch 77/100 loss: 0.0209 - mae: 0.1064 - val_loss: 0.0517 - val_mae: 0.1172
# Epoch 78/100 loss: 0.0189 - mae: 0.1022 - val_loss: 0.0540 - val_mae: 0.1178
# Epoch 79/100 loss: 0.0188 - mae: 0.1011 - val_loss: 0.0577 - val_mae: 0.1281
# Epoch 80/100 loss: 0.0171 - mae: 0.0982 - val_loss: 0.0371 - val_mae: 0.1011
# Epoch 81/100 loss: 0.0232 - mae: 0.1098 - val_loss: 0.0521 - val_mae: 0.1236
# Epoch 82/100 loss: 0.0178 - mae: 0.0956 - val_loss: 0.0493 - val_mae: 0.1084
# Epoch 83/100 loss: 0.0177 - mae: 0.1009 - val_loss: 0.0501 - val_mae: 0.1225
# Epoch 84/100 loss: 0.0205 - mae: 0.1071 - val_loss: 0.0479 - val_mae: 0.1130
# Epoch 85/100 loss: 0.0199 - mae: 0.1041 - val_loss: 0.0459 - val_mae: 0.1121
# Epoch 86/100 loss: 0.0189 - mae: 0.1021 - val_loss: 0.0627 - val_mae: 0.1403
# Epoch 87/100 loss: 0.0180 - mae: 0.0958 - val_loss: 0.0574 - val_mae: 0.1192
# Epoch 88/100 loss: 0.0169 - mae: 0.0953 - val_loss: 0.0453 - val_mae: 0.1095
# Epoch 89/100 loss: 0.0159 - mae: 0.0944 - val_loss: 0.0416 - val_mae: 0.1078
# Epoch 90/100 loss: 0.0182 - mae: 0.0972 - val_loss: 0.0433 - val_mae: 0.1079
# Epoch 91/100 loss: 0.0177 - mae: 0.0947 - val_loss: 0.0483 - val_mae: 0.1139
# Epoch 92/100 loss: 0.0163 - mae: 0.0944 - val_loss: 0.0562 - val_mae: 0.1359
# Epoch 93/100 loss: 0.0176 - mae: 0.0941 - val_loss: 0.0515 - val_mae: 0.1252
# Epoch 94/100 loss: 0.0184 - mae: 0.0981 - val_loss: 0.0412 - val_mae: 0.1129
# Epoch 95/100 loss: 0.0175 - mae: 0.0953 - val_loss: 0.0557 - val_mae: 0.1291
# Epoch 96/100 loss: 0.0185 - mae: 0.0998 - val_loss: 0.0539 - val_mae: 0.1197
# Epoch 97/100 loss: 0.0200 - mae: 0.1006 - val_loss: 0.0799 - val_mae: 0.1642
# Epoch 98/100 loss: 0.0178 - mae: 0.0969 - val_loss: 0.0374 - val_mae: 0.1051
# Epoch 99/100 loss: 0.0227 - mae: 0.1140 - val_loss: 0.0622 - val_mae: 0.1396
# Epoch 100/100 loss: 0.0225 - mae: 0.1061 - val_loss: 0.0604 - val_mae: 0.1305
# [0.10611342551077113, 0.13047033920884132]

# %%
test_output = test_sales_std [MIN:]
naive_prediction = test_sales_std[MIN-1:-1]
mean_squared_error = np.mean(np.square(naive_prediction
                                       - test_output))
mean_abs_error = np. mean(np.abs (naive_prediction
                                  - test_output))
print ('naive test mse: ', mean_squared_error)
print ('naive test mean abs: ', mean_abs_error)
# Out:
# naive test mse:  0.4723033
# naive test mean abs:  0.48052385

# %%
# Use trained model to predict the test data
inputs = torch.from_numpy(test_X)
inputs = inputs.to(device)
outputs = model(inputs)
predicted_test = outputs.cpu().detach().numpy()
# De-standardize output.
predicted_test = np.reshape (predicted_test,
                             (len(predicted_test)))
predicted_test = predicted_test * stddev + mean

# Plot test prediction.
x = range(len(test_sales) -MIN)
plt.plot(x, predicted_test, 'm-',
         label='predicted test_output')
plt.plot(x, test_sales[-(len(test_sales)-MIN):],
         'g-', label='actual test_output')
plt.title('Book sales') 
plt.axis([0, 55, 0.0, 3000.0]) 
plt.xlabel ('months')
plt.ylabel ('Predicted book sales')
plt.legend()
plt.show()
